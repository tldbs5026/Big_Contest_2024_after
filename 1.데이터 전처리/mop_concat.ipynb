# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path = '/content/drive/MyDrive/workspace/kaggle&github/~09.30_빅콘테스트/data/제주_관광_데이터/제주 관광지 평점리뷰 형태소 데이터'
data = pd.read_csv(path +'/JT_PORTAL_SITE_AVRG_SCORE_REVIEW_MOP_INFO_202301.csv')
data.head()

months = ['202302','202303','202304','202305','202306','202307','202308','202309','202310','202311','202312']

for month in months :
    df_tmp = pd.read_csv(path +f'/JT_PORTAL_SITE_AVRG_SCORE_REVIEW_MOP_INFO_{month}.csv')
    data = pd.merge(data,df_tmp, how = 'outer')

data

# %%
data.to_csv(path + '/mop_total.csv')
